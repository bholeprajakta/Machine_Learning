# %% [markdown]
# # Problem Statement 1:

# %% [markdown]
# ## Importing libraries and dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("E:\datascience\MACHINE LEARNING\ML_Exam\car.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# ## 1.Data understanding and exploration

# %%
df.shape
# Out:
# (301, 9)

# %% [raw]
# There are 301 rows and 9 columns in dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# ### categorical variable

# %%
df['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
# ...

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
plt.figure(figsize=(15,2))
sns.countplot(df['Car_Name'])
plt.xticks(rotation=90)
plt.show()
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#city car has highest count

# %%
sns.countplot(df['Fuel_Type'])
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fuel_Type', ylabel='count'>

# %%
#fuel-type petrol is maximum used in cars

# %%
sns.countplot(df['Seller_Type'])
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Seller_Type', ylabel='count'>

# %%
#Dealer seller count are maximum compared to individual

# %%
sns.countplot(df['Transmission'])
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Transmission', ylabel='count'>

# %%
#Manual transmission is maximum as compared to automatic

# %% [markdown]
# # 2.Data cleaning

# %%
#checking missing values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#no null values in dataset

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 3], dtype=int64)

# %%
final_df=df[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Car_Name','Owner']]

# %%
final_df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission Car_Name  Owner
# 0         Manual     ritz      0
# ...

# %%
final_df['current_year']=2022
# Out:
# C:\Users\bhole\AppData\Local\Temp\ipykernel_23640\3289497290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['current_year']=2022

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission Car_Name  Owner  current_year
# 0       Manual     ritz      0          2022
# 1       Manual      sx4      0          2022
# 2       Manual     ciaz      0          2022
# 3       Manual  wagon r      0          2022
# 4       Manual    swift      0          2022

# %%
final_df['no_year']=final_df['current_year']-final_df['Year']
# Out:
# C:\Users\bhole\AppData\Local\Temp\ipykernel_23640\1498032154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['no_year']=final_df['current_year']-final_df['Year']

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission Car_Name  Owner  current_year  no_year
# 0       Manual     ritz      0          2022        8
# 1       Manual      sx4      0          2022        9
# 2       Manual     ciaz      0          2022        5
# 3       Manual  wagon r      0          2022       11
# 4       Manual    swift      0          2022        8

# %%
final_df.drop(['Year'],axis=1,inplace=True)
# Out:
# C:\Users\bhole\AppData\Local\Temp\ipykernel_23640\1797776382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(['Year'],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission Car_Name  Owner  current_year  no_year
# 0       Manual     ritz      0          2022        8
# 1       Manual      sx4      0          2022        9
# 2       Manual     ciaz      0          2022        5
# 3       Manual  wagon r      0          2022       11
# 4       Manual    swift      0          2022        8

# %%
final_df.drop(['Car_Name'],axis=1,inplace=True)

# %% [markdown]
# # 3.Data preparation

# %%
final_df=pd.get_dummies(final_df)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  current_year  no_year  \
# 0           3.35           5.59       27000      0          2022        8
# 1           4.75           9.54       43000      0          2022        9
# 2           7.25           9.85        6900      0          2022        5
# 3           2.85           4.15        5200      0          2022       11
# 4           4.60           6.87       42450      0          2022        8
#
#    Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0              0                 0                 1                   1
# 1              0                 1                 0                   1
# 2              0                 0                 1                   1
# 3              0                 0                 1                   1
# 4              0                 1                 0                   1
#
#    Seller_Type_Individual  Transmission_Automatic  Transmission_Manual
# ...

# %%
final_df.shape
# Out:
# (301, 13)

# %%
final_df.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# current_year                      NaN            NaN         NaN       NaN
# no_year                     -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_CNG               -0.025164      -0.011500    0.012223 -0.014272
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Dealer           0.550724       0.512030    0.101419 -0.124269
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# ...

# %%
sns.pairplot(final_df)

# %%
sns.heatmap(final_df.corr())
# Out:
# <AxesSubplot:>

# %%
#independent variable
x=final_df.iloc[:,1:]
x.head()
# Out:
#    Present_Price  Kms_Driven  Owner  current_year  no_year  Fuel_Type_CNG  \
# 0           5.59       27000      0          2022        8              0
# 1           9.54       43000      0          2022        9              0
# 2           9.85        6900      0          2022        5              0
# 3           4.15        5200      0          2022       11              0
# 4           6.87       42450      0          2022        8              0
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0                 0                 1                   1
# 1                 1                 0                   1
# 2                 0                 1                   1
# 3                 0                 1                   1
# 4                 1                 0                   1
#
#    Seller_Type_Individual  Transmission_Automatic  Transmission_Manual
# 0                       0                       0                    1
# ...

# %%
#dependent variable
y=final_df.iloc[:,0]
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
x
# Out:
#      Present_Price  Kms_Driven  Owner  current_year  no_year  Fuel_Type_CNG  \
# 0             5.59       27000      0          2022        8              0
# 1             9.54       43000      0          2022        9              0
# 2             9.85        6900      0          2022        5              0
# 3             4.15        5200      0          2022       11              0
# 4             6.87       42450      0          2022        8              0
# ..             ...         ...    ...           ...      ...            ...
# 296          11.60       33988      0          2022        6              0
# 297           5.90       60000      0          2022        7              0
# 298          11.00       87934      0          2022       13              0
# 299          12.50        9000      0          2022        5              0
# 300           5.90        5464      0          2022        6              0
#
# ...

# %%
y=y.values

# %%
#here use ExtraTreeRegressor algo .it is similar to random forest, create many decision tree, but the sampling of tree is random
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [3.75078369e-01 3.80104904e-02 4.73183086e-04 0.00000000e+00
#  7.90482285e-02 7.62569306e-05 2.14828668e-01 1.61212603e-02
#  1.30933745e-01 4.19491740e-03 5.73701790e-02 8.38647033e-02]

# %%
feature_importances=pd.Series(model.feature_importances_,index=x.columns)

# %%
feature_importances
# Out:
# Present_Price             0.375078
# Kms_Driven                0.038010
# Owner                     0.000473
# current_year              0.000000
# no_year                   0.079048
# Fuel_Type_CNG             0.000076
# Fuel_Type_Diesel          0.214829
# Fuel_Type_Petrol          0.016121
# Seller_Type_Dealer        0.130934
# Seller_Type_Individual    0.004195
# Transmission_Automatic    0.057370
# Transmission_Manual       0.083865
# dtype: float64

# %% [markdown]
# ## scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %% [markdown]
# ## split the data

# %%
#split the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[ 0.15081886,  1.18624791, -0.17450057, ..., -0.73728539,
#         -0.39148015,  0.39148015],
#        [-0.37063343, -0.34099547, -0.17450057, ..., -0.73728539,
#         -0.39148015,  0.39148015],
#        [ 3.31429608, -0.7971516 , -0.17450057, ..., -0.73728539,
#          2.55440795, -2.55440795],
#        ...,
#        [-0.66380549, -0.59108412, -0.17450057, ...,  1.35632689,
#         -0.39148015,  0.39148015],
#        [-0.40307935,  0.72259608, -0.17450057, ..., -0.73728539,
#         -0.39148015,  0.39148015],
#        [-0.80981213, -0.59881165, -0.17450057, ...,  1.35632689,
#         -0.39148015,  0.39148015]])

# %%
y_train
# Out:
# array([ 4.9 ,  2.  , 33.  ,  3.75,  5.65,  8.55,  3.8 ,  0.4 ,  2.65,
#         2.85,  2.65,  0.48,  6.15,  0.31,  6.  ,  0.55,  9.15,  0.35,
#         2.25,  0.45, 17.  ,  4.85,  5.75,  6.45,  1.1 ,  5.35,  5.5 ,
#         0.6 ,  5.3 ,  0.65,  6.  ,  8.99,  1.25,  5.2 ,  0.2 ,  0.5 ,
#         0.45,  1.45,  2.75,  3.1 ,  3.25,  0.42,  5.4 ,  0.95,  0.9 ,
#         4.5 ,  3.  ,  5.95,  3.1 , 10.11,  3.15,  0.48,  0.45,  6.  ,
#        12.5 ,  0.65,  7.9 ,  6.95,  0.48,  2.1 ,  1.2 ,  4.9 ,  7.45,
#         0.4 ,  7.25,  4.5 ,  3.95,  1.2 ,  5.3 ,  3.1 ,  4.6 , 20.75,
#         0.42,  4.5 ,  9.25,  0.6 ,  0.1 ,  0.5 ,  5.25,  5.85,  0.25,
#         6.1 ,  1.25,  0.15,  2.85,  0.45,  0.9 ,  2.9 ,  3.1 ,  1.5 ,
#         6.  ,  0.25,  2.65, 10.25,  3.9 ,  8.35, 14.73, 23.  ,  7.25,
#        11.25,  1.35,  0.3 , 35.  ,  2.85,  0.2 ,  4.1 ,  2.55,  2.25,
#         0.48, 14.9 ,  2.9 ,  9.1 ,  1.  ,  4.1 , 18.75,  0.2 ,  4.95,
# ...

# %% [markdown]
# # 4.Model building and evaluation

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=20,random_state=0)
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=20, random_state=0)

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([ 7.23  ,  0.43  ,  4.5725,  8.9995, 15.204 ,  5.3475,  3.2125,
#         0.4275,  3.685 ,  4.685 ,  2.7525,  0.7575,  4.815 ,  6.875 ,
#         7.71  , 15.58  ,  6.4975,  4.0775,  0.432 ,  1.5675,  3.1725,
#         4.91  ,  5.0425,  9.6635,  0.174 ,  0.7525,  0.3075,  0.698 ,
#         0.485 ,  3.857 ,  2.4825,  6.0125,  0.494 ,  7.5925,  3.057 ,
#         1.165 ,  5.4325,  5.2975,  0.204 ,  8.4275,  7.8725, 23.57  ,
#         4.8775,  4.4425,  5.69  , 10.59  ,  0.248 ,  0.795 ,  5.4025,
#         6.61  ,  6.091 ,  3.05  ,  5.1225, 25.245 ,  1.1655,  1.1335,
#         0.4505,  2.1625,  3.425 ,  2.5775,  3.885 ])

# %%
np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1)
# Out:
# array([[ 7.23  ,  8.25  ],
#        [ 0.43  ,  0.5   ],
#        [ 4.5725,  5.25  ],
#        [ 8.9995,  9.5   ],
#        [15.204 , 18.    ],
#        [ 5.3475,  5.5   ],
#        [ 3.2125,  3.75  ],
#        [ 0.4275,  0.45  ],
#        [ 3.685 ,  4.5   ],
#        [ 4.685 ,  4.5   ],
#        [ 2.7525,  2.7   ],
#        [ 0.7575,  0.72  ],
#        [ 4.815 ,  5.25  ],
#        [ 6.875 ,  7.5   ],
#        [ 7.71  ,  7.75  ],
#        [15.58  , 19.75  ],
#        [ 6.4975,  7.4   ],
#        [ 4.0775,  4.75  ],
#        [ 0.432 ,  0.35  ],
#        [ 1.5675,  1.7   ],
#        [ 3.1725,  4.4   ],
#        [ 4.91  ,  5.25  ],
#        [ 5.0425,  5.11  ],
#        [ 9.6635, 11.25  ],
#        [ 0.174 ,  0.2   ],
#        [ 0.7525,  0.78  ],
#        [ 0.3075,  0.38  ],
#        [ 0.698 ,  0.65  ],
#        [ 0.485 ,  0.5   ],
#        [ 3.857 ,  3.6   ],
#        [ 2.4825,  3.25  ],
#        [ 6.0125,  7.2   ],
#        [ 0.494 ,  0.6   ],
#        [ 7.5925,  8.75  ],
# ...

# %%
y_test
# Out:
# array([ 8.25,  0.5 ,  5.25,  9.5 , 18.  ,  5.5 ,  3.75,  0.45,  4.5 ,
#         4.5 ,  2.7 ,  0.72,  5.25,  7.5 ,  7.75, 19.75,  7.4 ,  4.75,
#         0.35,  1.7 ,  4.4 ,  5.25,  5.11, 11.25,  0.2 ,  0.78,  0.38,
#         0.65,  0.5 ,  3.6 ,  3.25,  7.2 ,  0.6 ,  8.75,  3.  ,  1.15,
#         6.6 ,  4.75,  0.25,  8.25,  9.25, 19.99,  5.5 ,  4.75,  5.5 ,
#        12.9 ,  0.3 ,  1.05,  5.25,  6.5 ,  7.5 ,  2.9 ,  4.8 , 23.5 ,
#         1.2 ,  1.1 ,  0.65,  2.55,  4.15,  1.35,  3.51])

# %%
y_pred
# Out:
# array([ 7.23  ,  0.43  ,  4.5725,  8.9995, 15.204 ,  5.3475,  3.2125,
#         0.4275,  3.685 ,  4.685 ,  2.7525,  0.7575,  4.815 ,  6.875 ,
#         7.71  , 15.58  ,  6.4975,  4.0775,  0.432 ,  1.5675,  3.1725,
#         4.91  ,  5.0425,  9.6635,  0.174 ,  0.7525,  0.3075,  0.698 ,
#         0.485 ,  3.857 ,  2.4825,  6.0125,  0.494 ,  7.5925,  3.057 ,
#         1.165 ,  5.4325,  5.2975,  0.204 ,  8.4275,  7.8725, 23.57  ,
#         4.8775,  4.4425,  5.69  , 10.59  ,  0.248 ,  0.795 ,  5.4025,
#         6.61  ,  6.091 ,  3.05  ,  5.1225, 25.245 ,  1.1655,  1.1335,
#         0.4505,  2.1625,  3.425 ,  2.5775,  3.885 ])

# %%
sns.distplot(y_test)
# Out:
# E:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(y_pred)
# Out:
# E:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(y_pred,y_test)

# %% [markdown]
# # 5.Result with error calculation

# %%
#mean squared error
from sklearn.metrics import mean_squared_error,mean_absolute_error
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.6293196721311477

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 1.1034715204918037

# %%
#root means squared error
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 1.0504625269336378
